# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavya820/Kavya820/blob/master/Copy_of_first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Mon Sep  7 06:56:27 2020

# %%
time.sleep(5)
print(time.ctime())
# Out:
# Mon Sep  7 06:58:27 2020

# %% [markdown]
# this is **bold**
# this is *italic*
# this is ~strikethrough~
# this is ***bold and italic***

# %% [markdown]
# $\sqrt{3x-1}+(1+x)^2$

# %%
import numpy as np
from matplotlib import pyplot as plt
y = np.random.randn(100)
x = [x for x in range(len(y))]
plt.plot(x, y)
plt.title("Sample Plot")
plt.show()
